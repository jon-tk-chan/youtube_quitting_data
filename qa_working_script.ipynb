# %%
# !pip install transformers
# !pip install torch
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 4.9 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 50.4 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 57.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.0 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.6

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
import pandas as pd
import json
import unidecode

from google.colab import drive
drive.mount('/content/drive')
#authorize to your gmail account in the popout window
#base folder: 'content -> drive OR sample_data'
# Out:
# Mounted at /content/drive

# %%
model_name = AutoModelForQuestionAnswering.from_pretrained("deepset/tinyroberta-squad2")
tokenizer_name = AutoTokenizer.from_pretrained('deepset/bert-base-cased-squad2')
# Out:
# Downloading:   0%|          | 0.00/835 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/326M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/152 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
model_name = "deepset/tinyroberta-squad2"
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
# Out:
# Downloading:   0%|          | 0.00/383 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
#format: "[CLS] <context> [SEP] <question> [SEP] [PAD] [PAD]"
#format is always the open token, context ssquence and question sequence, separated by a sep token, then padding

# %%
##### 
filename = "/content/sample_data/processed_ALL.json"
with open(filename, 'r') as f:
  data = json.load(f)

data.keys()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0f1a68841f8c> in <module>
#       1 #####
#       2 filename = "/content/sample_data/processed_ALL.json"
# ----> 3 with open(filename, 'r') as f:
#       4   data = json.load(f)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/processed_ALL.json'

# %%
i = 0
questions= [
    'What was his or her job?',
    'Why did they quit?',
    'What is the main reason for him or her to quit?'
]

to_df = {
    "id": [],
    "prev_job": [],
    "quit_rsn1": [],
    "quit_rsn2": []
    
}

for id, item in data.items():
  context = item['str']

  qa_0 = nlp({
    'question': questions[0],
    'context': context
  })

  qa_1 = nlp({
    'question': questions[1],
    'context': context
  })

  qa_2 = nlp({
    'question': questions[2],
    'context': context
  })

  print(id)
  # print(qa_0['answer'])
  # print(qa_1['answer'])
  # print(qa_2['answer'])

  prev_job = qa_0['answer']
  reason1 = unidecode.unidecode(qa_1['answer'])
  reason2= unidecode.unidecode(qa_2['answer'])
  to_df['id'].append(id)
  to_df['prev_job'].append(prev_job)
  to_df['quit_rsn1'].append(reason1)
  to_df['quit_rsn2'].append(reason2)
  i +=1
  # if i == 5:
  #   break
# Out:
# XXyk_PT9LiM
# S_D4yJavp8M
# PgfzN1xfgLc
# EcojyBV4QJ4
# -lXuicxlnN4

# %%
out_df = pd.DataFrame(to_df)
out_df.to_csv("quitting_qa_out.csv")

# %%
out_df.head()
# Out:
#             id           prev_job                                  quit_rsn1  \
# 0  XXyk_PT9LiM   corporate lawyer              to start my own legal company
# 1  S_D4yJavp8M  salaried employee  they're  throwing in the towel in droves.
# 2  PgfzN1xfgLc  corporate finance                      without a backup plan
# 3  EcojyBV4QJ4  software engineer              to go run their own start-ups
# 4  -lXuicxlnN4         consultant                                   personal
#
#                             quit_rsn2
# 0       10 words that changed my life
# 1                             savings
# 2  everybody's situation is different
# 3       to go run their own start-ups
# 4                            personal
